# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import numpy as np

from google.cloud import bigquery
client = bigquery.Client()

sql_file_path = './sql/validator_timing_games_apr.sql'
with open(sql_file_path, 'r') as file:
    query = file.read()

df = client.query(query).to_dataframe()

# %%
lime = '#caff00'
teal = '#00ff99'
green = '#00d37f'
navy = '#171c47'
dark_navy = '#171530'
title_color = green
label_color = green
chart_background_color = navy
chart_color = lime

df.head(10)
# Out:
#                validator_operator  num_blocks  reorged  avg_ms_diff  \
# 0                   lido - skillz        2116        2  1933.310491
# 1  lido - attestant (bvi) limited        1972        0  1204.167850
# 2              lido - bridgetower        2268       22   941.509259
# 3                     lido - dsrv        1961        0   694.278939
# 4              lido - sigma prime        1055        2   663.735545
# 5               binance - unknown        8156        4   623.682565
# 6  lido - p2p.org - p2p validator        1692        2   574.711584
# 7                lido - chainsafe        1352        4   558.717456
# 8               p2p.org - unknown        1008        1   457.920635
# 9                kraken - unknown        4150       14   430.529880
#
#   gained_via_timing lost_via_reorg total_payload_value_eth  \
# 0      35.020941623    0.305225289           289.536284313
# 1      30.546332115           0E-9           303.757696868
# 2      22.469873949    2.117377067           302.625627764
# 3      13.415062030           0E-9           264.300577051
# 4      13.850117097    0.276126528           285.756441405
# 5      48.256625933    0.276287506          1015.479495505
# 6       8.096588207    0.461067147           206.462712052
# 7       8.851729236    0.573681977           205.959944923
# 8       4.759464617    0.066446170           116.841234520
# 9      14.657257776    1.204908942           500.787889813
#
#   lost_perc_via_reorg gained_perc_via_timiing
# 0         0.105418700            12.095527800
# 1                0E-9            10.056150800
# 2         0.699668800             7.424973900
# 3                0E-9             5.075684000
# 4         0.096630000             4.846825900
# 5         0.027207600             4.752102400
# 6         0.223317400             3.921574100
# 7         0.278540600             4.297791600
# 8         0.056868800             4.073446000
# 9         0.240602700             2.926839500
